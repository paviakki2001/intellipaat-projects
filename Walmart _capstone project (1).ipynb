# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# In this dataset there are exactly 45 different stores.And we need to select any 5 stores from it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv(r"C:\Users\91936\Contacts\Downloads\drive-download-20230709T122717Z-001-1-1-1\Walmart DataSet\Walmart DataSet.csv")
data1.set_index('Date', inplace=True)
# There are about 45 different stores in this dataset. Lets select the any store id from 1-45
a= int(input("Enter the store id:"))
store = data1[data1.Store == a]
sales = pd.DataFrame(store.Weekly_Sales.groupby(store.index).sum())
sales.dtypes
# Out:
# Enter the store id:23
# Weekly_Sales    float64
# dtype: object

# %%
sales.head(20)
# Out:
#             Weekly_Sales
# Date
# 01-04-2011    1182694.95
# 01-06-2012    1476144.34
# 01-07-2011    1492507.44
# 01-10-2010    1129909.44
# 02-03-2012    1322852.20
# 02-04-2010    1556627.62
# 02-07-2010    1549113.18
# 02-09-2011    1464295.69
# 02-12-2011    1552886.59
# 03-02-2012    1261872.67
# 03-06-2011    1562161.97
# 03-08-2012    1416926.31
# 03-09-2010    1405119.23
# 03-12-2010    1617025.41
# 04-02-2011    1159438.53
# 04-03-2011    1301185.28
# 04-05-2012    1317379.68
# 04-06-2010    1514435.51
# 04-11-2011    1428436.33
# 05-02-2010    1364721.58

# %%
y1=sales.Weekly_Sales
y2=sales5.Weekly_Sales

# %%
y1['2012'].plot(figsize=(15, 6),legend=True, color = 'chocolate')
y2['2012'].plot(figsize=(15, 6), legend=True, color = 'turquoise')
plt.ylabel('Weekly Sales')
plt.title('Store4 vs Store5 on 2012', fontsize = '16')
plt.show()

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 5)
import itertools
# Generate all different combinations of p, d and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, d and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]

# %%
plt.style.use('seaborn-pastel')
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2012-07-27'), dynamic=False)
pred_ci = pred.conf_int()

# %%
ax = y1['2010':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')
plt.legend()

plt.show()
# Out:
# <ipython-input-25-4d1356b90131>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   ax = y1['2010':].plot(label='observed')

# %%
y_forecasted = pred.predicted_mean
y_truth = y1['2012-7-27':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 103796418327.49

# %%
pred_dynamic = results.get_prediction(start=pd.to_datetime('2012-7-27'), dynamic=True, full_results=True)
pred_dynamic_ci = pred_dynamic.conf_int()

# %%
ax = y1['2010':].plot(label='observed', figsize=(12, 8))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_ci.index,
                pred_dynamic_ci.iloc[:, 0],
                pred_dynamic_ci.iloc[:, 1], color='k', alpha=.25)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2012-7-26'), y1.index[-1],
                 alpha=.1, zorder=-1)

ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')

plt.legend()
plt.show()
# Out:
# <ipython-input-28-35c4ed5f978a>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   ax = y1['2010':].plot(label='observed', figsize=(12, 8))

# %%
import numpy as np
# Extract the predicted and true values of our time series
y_forecasted = pred_dynamic.predicted_mean
print(y_forecasted)
# Out:
# Date
# 2012-07-27    1.126589e+06
# 2010-08-27    1.234269e+06
# 2011-01-28    4.524565e+05
# 2010-05-28    1.196748e+06
# 2012-09-28    7.609628e+05
# 2011-10-28    7.575154e+05
# 2011-04-29    8.080128e+05
# 2012-06-29   -6.516674e+04
# 2011-07-29    4.527270e+05
# 2010-10-29    2.352011e+05
# 2012-03-30    2.210719e+04
# 2010-04-30   -1.554845e+04
# 2010-07-30   -2.677521e+05
# 2011-09-30   -1.950111e+05
# 2011-12-30   -7.345009e+05
# 2012-08-31   -8.030586e+05
# 2010-12-31   -8.440126e+05
# Name: predicted_mean, dtype: float64

# %%
y_truth = y1['2012-7-27':]

print(y_truth)
# Out:
# Date
# 2012-07-27    1322932.36
# 2010-08-27    1584623.36
# 2011-01-28    1083657.61
# 2010-05-28    1571158.56
# 2012-09-28    1319035.06
# 2011-10-28    1407191.96
# 2011-04-29    1173307.40
# 2012-06-29    1451782.16
# 2011-07-29    1319767.55
# 2010-10-29    1112871.23
# 2012-03-30    1261964.96
# 2010-04-30    1259414.52
# 2010-07-30    1319773.55
# 2011-09-30    1275597.85
# 2011-12-30    1213486.95
# 2012-08-31    1577468.78
# 2010-12-31    1169773.85
# Name: Weekly_Sales, dtype: float64

# %%
# Compute the Root mean square error
rmse = np.sqrt(((y_forecasted - y_truth) ** 2).mean())
print('The Root Mean Squared Error of our forecasts is {}'.format(round(rmse, 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 1254466.57

# %%
Residual= y_forecasted - y_truth
print("Residual for Store1",np.abs(Residual).sum())
# Out:
# Residual for Store1 18302268.56744499

# %%
pred_uc = results.get_forecast(steps=12)

print(pred_uc)
# Out:
# <statsmodels.tsa.statespace.mlemodel.PredictionResultsWrapper object at 0x0000020B2A6F0910>
# C:\Users\91936\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

# %%
ax = y1.plot(label='observed', figsize=(12, 8))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')

plt.legend()
plt.show()
